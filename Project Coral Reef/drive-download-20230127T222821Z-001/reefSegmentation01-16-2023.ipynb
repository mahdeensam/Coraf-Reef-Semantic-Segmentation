# %%
# https://youtu.be/XyX5HNuv-xE
"""
Author: Dr. Sreenivas Bhattiprolu
Multiclass semantic segmentation using U-Net
Including segmenting large images by dividing them into smaller patches 
and stiching them back
To annotate images and generate labels, you can use APEER (for free):
www.apeer.com 
"""
# Out:
# '\nAuthor: Dr. Sreenivas Bhattiprolu\nMulticlass semantic segmentation using U-Net\nIncluding segmenting large images by dividing them into smaller patches \nand stiching them back\nTo annotate images and generate labels, you can use APEER (for free):\nwww.apeer.com \n'

# %%
#imports and dependencies
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.utils import normalize
import os
import glob
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
#let's set up the structure of our model:
def multi_unet_model(n_classes=3, IMG_HEIGHT=244, IMG_WIDTH=244, IMG_CHANNELS=3):
#Build the model
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    #s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
     
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    print(c4.shape)
    c4 = Dropout(0.2)(c4)
    print(c4.shape)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    print(c4.shape)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
    
    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    
    #NOTE: Compile the model in the main program to make it easy to test with various loss functions
    #model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    
    #model.summary()
    
    return model#, c9 to get features

# %%
#mount drive and set up directories

from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
#Resizing images, if needed
SIZE_X = 224 
SIZE_Y = 224
n_classes=3 #Number of classes for segmentation

# %%
#Capture training image info as a list


#original images must be in same order as masks in folder
train_images = []
imgPath ="/content/drive/MyDrive/Coral_Reef_Metadata/Annotated_Arrays/"
                                #path to training imgs
for directory_path in os.listdir(imgPath):
    print(directory_path)
    arr = np.load(imgPath+directory_path)
    orig = arr["image"]     
    img = cv2.resize(orig, (SIZE_Y, SIZE_X))
    train_images.append(img)

#Convert list to array for machine learning processing        
train_images = np.array(train_images)
print(train_images.shape)
# Out:
# _edgesA_BS_Mira-por-vos_Islets_NIR_GD.npz
# _edgesA_BZ_Glovers Reef_NIR_gd.npz
# _edgesA_BZ_Lighthouse_Reef_NIR_gd.npz
# _edgesA_MX_Chinchorro_Bank_NIR_GD.npz
# _edgesI_GB_Saloman_NIR_GD.npz
# _edgesP_PF_Aratika_Atoll_NIR_DH.npz
# _edgesI_MV_Maldives_Group_16_NIR_GD.npz
# _edgesP_PF_Arutua_Atoll_NIR_DH.npz
# _edgesI_MV_Maldives_Group_7_NIR_GD.npz
# _edgesI_MV_Maldives_Group_18_NIR_GD.npz
# _edgesP_PF_Faaite_Atoll_NIR_DH.npz
# _edgesI_IN_Kadmat_Island_NIR_Enter-user-ID.npz
# _edgesI_IN_Agatti_Atoll_NIR_Enter-user-ID.npz
# _edgesI_IN_Kitlan_Island_NIR_Enter-user-ID.npz
# _edgesI_MU_Mapare_Islet_NIR_Enter-user-ID.npz
# _edgesI_MU_Ile_Raphael_NIR_Enter-user-ID.npz
# _edgesP_PF_Fakahina_Atoll_NIR_DH.npz
# _edgesP_PF_Fakarava_Atoll_NIR_DH.npz
# _edgesP_PF_Fangatau_Atoll_NIR_DH.npz
# _edgesP_PF_Fangataufa_Atoll_NIR_DH.npz
# _edgesP_PF_Hao_Atoll_NIR_DH.npz
# _edgesP_PF_Haraiki_Atoll_NIR_DH.npz
# _edgesP_PF_Hikueru_Atoll_NIR_Enter-user-ID.npz
# _edgesP_PF_Hiti_Atoll_NIR_Enter-user-ID.npz
# _edgesP_PF_Huahine_Island_NIR_Enter-user-ID.npz
# _edgesP_PF_Katiu_Atoll_NIR_DH.npz
# _edgesP_FJ_Yagasa_NIR_Enter-user-ID.npz
# _edgesP_GB_Nupani_Atoll_NIR_Enter-user-ID.npz
# _edgesP_FJ_Ketei_NIR_Enter-user-ID.npz
# _edgesP_PG_Pelleluhu_Islands_NIR_DH.npz
# _edgesP_FJ_Gau_Island_NIR_Enter-user-ID.npz
# _edgesP_PF_Kauehi_Atoll_NIR_DH.npz
# _edgesP_FJ_Fulqana_NIR_GD.npz
# _edgesP_PF_Kaukura_Atoll_NIR_DH.npz
# _edgesP_PF_Maiao_Atoll_NIR_DH.npz
# _edgesP_PF_Makatea_Atoll_NIR_DH.npz
# _edgesA_BZ_Turneffe_Reef_NIR_Enter-user-ID.npz
# _edgesI_MV_Maldives_Group_21_NIR_Enter-user-ID (1).npz
# _edgesI_MV_Maldives_Group_4_NIR_GD.npz
# _edgesP_GB_Three_Brothers_Island_NIR_Enter-user-ID (1).npz
# _edgesI_MV_Maldives_Group_14_NIR_Enter-user-ID (1).npz
# _edgesI_MV_Maldives_Group_6_NIR_Enter-user-ID.npz
# _edgesP_FJ_Wailangilala_Atoll_NIR_Enter-user-ID (1).npz
# _edgesI_MV_Maldives_Group_2_NIR_GD (1).npz
# _edgesP_PF_Makemo_Atoll_NIR_DH.npz
# _edgesP_ID_Dauwi_Island_NIR_GD.npz
# _edgesP_FJ_Batiki_Island_NIR_GD.npz
# _edgesP_FJ_Oneata_NIR_GD.npz
# _edgesP_FJ_Bell_Reef_NIR_GD.npz
# _edgesP_CR_Ifalik_Atoll_NIR_GD.npz
# _edgesP_FJ_Nairai_Island_NIR_GD.npz
# _edgesP_FJ_Thakau_Vuthovutho_Atoll_NIR_GD.npz
# _edgesP_FJ_Tova_Reef_NIR_GD.npz
# _edgesP_CR_Kuop_Atoll_NIR_GD.npz
# _edgesP_TV_Nukulaelae_Atoll_NIR_GD.npz
# _edgesI_MV_Maldives_Group_12_NIR_GD.npz
# _edgesP_FJ_Kanacea_Island_NIR_GD.npz
# _edgesI_IN_Cherbaniani_Reef_NIR_GD.npz
# _edgesI_SC_Aldabra_Atoll_NIR_GD.npz
# _edgesP_FJ_Oqea_NIR_GD.npz
# _edgesP_CN_Half_Moon_Shoal_NIR_GD.npz
# _edgesP_CR_Namoluk_Atoll_NIR_GD.npz
# _edgesP_FJ_Thakau_Nokeva_Atoll_NIR_GD.npz
# _edgesP_CR_Ngulu_Atoll_NIR_GD.npz
# _edgesI_MV_Maldives_Group_1_NIR_GD.npz
# _edgesP_ID_Pulau_Kayubutang_NIR_GD.npz
# _edgesP_FJ_Motua_Levu_Atoll_NIR_GD.npz
# _edgesA_CO_Albuquerque_Cays_NIR_GD.npz
# (68, 224, 224, 3)

# %%
#Capture mask/label info as a list
train_masks = [] 
                                #path to respective masks
for directory_path in os.listdir(imgPath):
    print(directory_path)
    arr = np.load(imgPath+directory_path)
    orig = arr["label"]     
    img = cv2.resize(orig, (SIZE_Y, SIZE_X))
    train_masks.append(img)


#Convert list to array for machine learning processing          
train_masks = np.array(train_masks)
print(str(train_masks.shape)+"\n"+str(train_masks.size))
# Out:
# _edgesA_BS_Mira-por-vos_Islets_NIR_GD.npz
# _edgesA_BZ_Glovers Reef_NIR_gd.npz
# _edgesA_BZ_Lighthouse_Reef_NIR_gd.npz
# _edgesA_MX_Chinchorro_Bank_NIR_GD.npz
# _edgesI_GB_Saloman_NIR_GD.npz
# _edgesP_PF_Aratika_Atoll_NIR_DH.npz
# _edgesI_MV_Maldives_Group_16_NIR_GD.npz
# _edgesP_PF_Arutua_Atoll_NIR_DH.npz
# _edgesI_MV_Maldives_Group_7_NIR_GD.npz
# _edgesI_MV_Maldives_Group_18_NIR_GD.npz
# _edgesP_PF_Faaite_Atoll_NIR_DH.npz
# _edgesI_IN_Kadmat_Island_NIR_Enter-user-ID.npz
# _edgesI_IN_Agatti_Atoll_NIR_Enter-user-ID.npz
# _edgesI_IN_Kitlan_Island_NIR_Enter-user-ID.npz
# _edgesI_MU_Mapare_Islet_NIR_Enter-user-ID.npz
# _edgesI_MU_Ile_Raphael_NIR_Enter-user-ID.npz
# _edgesP_PF_Fakahina_Atoll_NIR_DH.npz
# _edgesP_PF_Fakarava_Atoll_NIR_DH.npz
# _edgesP_PF_Fangatau_Atoll_NIR_DH.npz
# _edgesP_PF_Fangataufa_Atoll_NIR_DH.npz
# _edgesP_PF_Hao_Atoll_NIR_DH.npz
# _edgesP_PF_Haraiki_Atoll_NIR_DH.npz
# _edgesP_PF_Hikueru_Atoll_NIR_Enter-user-ID.npz
# _edgesP_PF_Hiti_Atoll_NIR_Enter-user-ID.npz
# _edgesP_PF_Huahine_Island_NIR_Enter-user-ID.npz
# _edgesP_PF_Katiu_Atoll_NIR_DH.npz
# _edgesP_FJ_Yagasa_NIR_Enter-user-ID.npz
# _edgesP_GB_Nupani_Atoll_NIR_Enter-user-ID.npz
# _edgesP_FJ_Ketei_NIR_Enter-user-ID.npz
# _edgesP_PG_Pelleluhu_Islands_NIR_DH.npz
# _edgesP_FJ_Gau_Island_NIR_Enter-user-ID.npz
# _edgesP_PF_Kauehi_Atoll_NIR_DH.npz
# _edgesP_FJ_Fulqana_NIR_GD.npz
# _edgesP_PF_Kaukura_Atoll_NIR_DH.npz
# _edgesP_PF_Maiao_Atoll_NIR_DH.npz
# _edgesP_PF_Makatea_Atoll_NIR_DH.npz
# _edgesA_BZ_Turneffe_Reef_NIR_Enter-user-ID.npz
# _edgesI_MV_Maldives_Group_21_NIR_Enter-user-ID (1).npz
# _edgesI_MV_Maldives_Group_4_NIR_GD.npz
# _edgesP_GB_Three_Brothers_Island_NIR_Enter-user-ID (1).npz
# _edgesI_MV_Maldives_Group_14_NIR_Enter-user-ID (1).npz
# _edgesI_MV_Maldives_Group_6_NIR_Enter-user-ID.npz
# _edgesP_FJ_Wailangilala_Atoll_NIR_Enter-user-ID (1).npz
# _edgesI_MV_Maldives_Group_2_NIR_GD (1).npz
# _edgesP_PF_Makemo_Atoll_NIR_DH.npz
# _edgesP_ID_Dauwi_Island_NIR_GD.npz
# _edgesP_FJ_Batiki_Island_NIR_GD.npz
# _edgesP_FJ_Oneata_NIR_GD.npz
# _edgesP_FJ_Bell_Reef_NIR_GD.npz
# _edgesP_CR_Ifalik_Atoll_NIR_GD.npz
# _edgesP_FJ_Nairai_Island_NIR_GD.npz
# _edgesP_FJ_Thakau_Vuthovutho_Atoll_NIR_GD.npz
# _edgesP_FJ_Tova_Reef_NIR_GD.npz
# _edgesP_CR_Kuop_Atoll_NIR_GD.npz
# _edgesP_TV_Nukulaelae_Atoll_NIR_GD.npz
# _edgesI_MV_Maldives_Group_12_NIR_GD.npz
# _edgesP_FJ_Kanacea_Island_NIR_GD.npz
# _edgesI_IN_Cherbaniani_Reef_NIR_GD.npz
# _edgesI_SC_Aldabra_Atoll_NIR_GD.npz
# _edgesP_FJ_Oqea_NIR_GD.npz
# _edgesP_CN_Half_Moon_Shoal_NIR_GD.npz
# _edgesP_CR_Namoluk_Atoll_NIR_GD.npz
# _edgesP_FJ_Thakau_Nokeva_Atoll_NIR_GD.npz
# _edgesP_CR_Ngulu_Atoll_NIR_GD.npz
# _edgesI_MV_Maldives_Group_1_NIR_GD.npz
# _edgesP_ID_Pulau_Kayubutang_NIR_GD.npz
# _edgesP_FJ_Motua_Levu_Atoll_NIR_GD.npz
# _edgesA_CO_Albuquerque_Cays_NIR_GD.npz
# (68, 224, 224, 3)
# 10235904

# %%
# ###############################################
# #Encode labels... but multi dim array so need to flatten, encode and reshape
# from sklearn.preprocessing import LabelEncoder
# labelencoder = LabelEncoder()
# n, h, w = train_masks.shape
# train_masks_reshaped = train_masks.reshape(-1,1)
# train_masks_reshaped_encoded = labelencoder.fit_transform(train_masks_reshaped)
# train_masks_encoded_original_shape = train_masks_reshaped_encoded.reshape(n, h, w)

# np.unique(train_masks_encoded_original_shape)

# #################################################

# %%
# train_images = np.expand_dims(train_images, axis=3)
# train_images = normalize(train_images, axis=1)

# train_masks_input = np.expand_dims(train_masks_encoded_original_shape, axis=3)

#Create a subset of data for quick testing
#Picking 10% for testing and remaining for training
from sklearn.model_selection import train_test_split

#here need to split data and order in a way that makes index in array correspond to particular image-mask pair
#DATA MATCHING BUG CAUSED HERE!
X1, X_test, y1, y_test = train_test_split(train_images, train_masks, test_size = 0.10, random_state = 0)

#Further split training data t0 a smaller subset for quick testing of models
X_train, X_do_not_use, y_train, y_do_not_use = train_test_split(X1, y1, test_size = 0.2, random_state = 0)

print("Class values in the dataset are ... ", np.unique(y_train))  # 0 is the background/few unlabeled 

from keras.utils import to_categorical
# train_masks_cat = to_categorical(y_train, num_classes=n_classes)
# y_train_cat = train_masks_cat.reshape((y_train.shape[0], y_train.shape[1], y_train.shape[2], n_classes))



# test_masks_cat = to_categorical(y_test, num_classes=n_classes)
# y_test_cat = test_masks_cat.reshape((y_test.shape[0], y_test.shape[1], y_test.shape[2], n_classes))
# Out:
# Class values in the dataset are ...  [0 1]

# %%
###############################################################
from sklearn.utils import class_weight
print(np.unique(train_masks))
# class_weights = class_weight.compute_class_weight(class_weight = "balanced",
#                                         classes = (0,1,2),
#                                         y = train_masks   )
# print("Class weights are...:", class_weights)


IMG_HEIGHT = X_train.shape[1]
IMG_WIDTH  = X_train.shape[2]
IMG_CHANNELS = X_train.shape[3]

def get_model():
    return multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS)

model = get_model()
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

#If starting with pre-trained weights. 
#model.load_weights('???.hdf5')

history = model.fit(X_train, y_train, 
                    batch_size = 4, 
                    verbose=1, 
                    epochs=35, 
                    validation_data=(X_test, y_test), 
                    #class_weight=class_weights,
                    shuffle=False)
                    


model.save('test.hdf5')
#model.save('sandstone_50_epochs_catXentropy_acc_with_weights.hdf5')
############################################################
# Out:
# [0 1]
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# (None, 28, 28, 128)
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  lambda_7 (Lambda)              (None, 224, 224, 3)  0           ['input_8[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 224, 224, 16  448         ['lambda_7[0][0]']
#                                 )
#
#  dropout_63 (Dropout)           (None, 224, 224, 16  0           ['conv2d_133[0][0]']
#                                 )
#
#  conv2d_134 (Conv2D)            (None, 224, 224, 16  2320        ['dropout_63[0][0]']
#                                 )
#
#  max_pooling2d_28 (MaxPooling2D  (None, 112, 112, 16  0          ['conv2d_134[0][0]']
#  )                              )
#
#  conv2d_135 (Conv2D)            (None, 112, 112, 32  4640        ['max_pooling2d_28[0][0]']
#                                 )
#
#  dropout_64 (Dropout)           (None, 112, 112, 32  0           ['conv2d_135[0][0]']
#                                 )
#
#  conv2d_136 (Conv2D)            (None, 112, 112, 32  9248        ['dropout_64[0][0]']
#                                 )
#
#  max_pooling2d_29 (MaxPooling2D  (None, 56, 56, 32)  0           ['conv2d_136[0][0]']
#  )
#
#  conv2d_137 (Conv2D)            (None, 56, 56, 64)   18496       ['max_pooling2d_29[0][0]']
#
#  dropout_65 (Dropout)           (None, 56, 56, 64)   0           ['conv2d_137[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 56, 56, 64)   36928       ['dropout_65[0][0]']
#
#  max_pooling2d_30 (MaxPooling2D  (None, 28, 28, 64)  0           ['conv2d_138[0][0]']
#  )
#
#  conv2d_139 (Conv2D)            (None, 28, 28, 128)  73856       ['max_pooling2d_30[0][0]']
#
#  dropout_66 (Dropout)           (None, 28, 28, 128)  0           ['conv2d_139[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 28, 28, 128)  147584      ['dropout_66[0][0]']
#
#  max_pooling2d_31 (MaxPooling2D  (None, 14, 14, 128)  0          ['conv2d_140[0][0]']
#  )
#
#  conv2d_141 (Conv2D)            (None, 14, 14, 256)  295168      ['max_pooling2d_31[0][0]']
#
#  dropout_67 (Dropout)           (None, 14, 14, 256)  0           ['conv2d_141[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 14, 14, 256)  590080      ['dropout_67[0][0]']
#
#  conv2d_transpose_28 (Conv2DTra  (None, 28, 28, 128)  131200     ['conv2d_142[0][0]']
#  nspose)
#
#  concatenate_28 (Concatenate)   (None, 28, 28, 256)  0           ['conv2d_transpose_28[0][0]',
#                                                                   'conv2d_140[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 28, 28, 128)  295040      ['concatenate_28[0][0]']
#
#  dropout_68 (Dropout)           (None, 28, 28, 128)  0           ['conv2d_143[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 28, 28, 128)  147584      ['dropout_68[0][0]']
#
#  conv2d_transpose_29 (Conv2DTra  (None, 56, 56, 64)  32832       ['conv2d_144[0][0]']
#  nspose)
#
#  concatenate_29 (Concatenate)   (None, 56, 56, 128)  0           ['conv2d_transpose_29[0][0]',
#                                                                   'conv2d_138[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 56, 56, 64)   73792       ['concatenate_29[0][0]']
#
#  dropout_69 (Dropout)           (None, 56, 56, 64)   0           ['conv2d_145[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 56, 56, 64)   36928       ['dropout_69[0][0]']
#
#  conv2d_transpose_30 (Conv2DTra  (None, 112, 112, 32  8224       ['conv2d_146[0][0]']
#  nspose)                        )
#
#  concatenate_30 (Concatenate)   (None, 112, 112, 64  0           ['conv2d_transpose_30[0][0]',
#                                 )                                 'conv2d_136[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 112, 112, 32  18464       ['concatenate_30[0][0]']
#                                 )
#
#  dropout_70 (Dropout)           (None, 112, 112, 32  0           ['conv2d_147[0][0]']
#                                 )
#
#  conv2d_148 (Conv2D)            (None, 112, 112, 32  9248        ['dropout_70[0][0]']
#                                 )
#
#  conv2d_transpose_31 (Conv2DTra  (None, 224, 224, 16  2064       ['conv2d_148[0][0]']
#  nspose)                        )
#
#  concatenate_31 (Concatenate)   (None, 224, 224, 32  0           ['conv2d_transpose_31[0][0]',
#                                 )                                 'conv2d_134[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 224, 224, 16  4624        ['concatenate_31[0][0]']
#                                 )
#
#  dropout_71 (Dropout)           (None, 224, 224, 16  0           ['conv2d_149[0][0]']
#                                 )
#
#  conv2d_150 (Conv2D)            (None, 224, 224, 16  2320        ['dropout_71[0][0]']
#                                 )
#
#  conv2d_151 (Conv2D)            (None, 224, 224, 3)  51          ['conv2d_150[0][0]']
#
# ==================================================================================================
# Total params: 1,941,139
# Trainable params: 1,941,139
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/35
# 12/12 [==============================] - 2s 96ms/step - loss: 1.2410 - accuracy: 0.7010 - val_loss: 1.0126 - val_accuracy: 0.8926
# Epoch 2/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.9505 - accuracy: 0.8213 - val_loss: 0.8545 - val_accuracy: 0.8302
# Epoch 3/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.6664 - accuracy: 0.8221 - val_loss: 0.4299 - val_accuracy: 0.8446
# Epoch 4/35
# 12/12 [==============================] - 0s 37ms/step - loss: 0.3025 - accuracy: 0.9005 - val_loss: 0.2037 - val_accuracy: 0.9408
# Epoch 5/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.2019 - accuracy: 0.9283 - val_loss: 0.2383 - val_accuracy: 0.9188
# Epoch 6/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1817 - accuracy: 0.9324 - val_loss: 0.1562 - val_accuracy: 0.9447
# Epoch 7/35
# 12/12 [==============================] - 0s 37ms/step - loss: 0.1626 - accuracy: 0.9376 - val_loss: 0.1464 - val_accuracy: 0.9468
# Epoch 8/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1497 - accuracy: 0.9403 - val_loss: 0.1392 - val_accuracy: 0.9501
# Epoch 9/35
# 12/12 [==============================] - 0s 42ms/step - loss: 0.1424 - accuracy: 0.9424 - val_loss: 0.1392 - val_accuracy: 0.9490
# Epoch 10/35
# 12/12 [==============================] - 0s 37ms/step - loss: 0.1349 - accuracy: 0.9445 - val_loss: 0.1369 - val_accuracy: 0.9503
# Epoch 11/35
# 12/12 [==============================] - 0s 37ms/step - loss: 0.1334 - accuracy: 0.9446 - val_loss: 0.1348 - val_accuracy: 0.9528
# Epoch 12/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1308 - accuracy: 0.9452 - val_loss: 0.1383 - val_accuracy: 0.9540
# Epoch 13/35
# 12/12 [==============================] - 0s 37ms/step - loss: 0.1286 - accuracy: 0.9457 - val_loss: 0.1462 - val_accuracy: 0.9538
# Epoch 14/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1267 - accuracy: 0.9462 - val_loss: 0.1386 - val_accuracy: 0.9539
# Epoch 15/35
# 12/12 [==============================] - 0s 37ms/step - loss: 0.1238 - accuracy: 0.9474 - val_loss: 0.1400 - val_accuracy: 0.9537
# Epoch 16/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1234 - accuracy: 0.9474 - val_loss: 0.1486 - val_accuracy: 0.9537
# Epoch 17/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1228 - accuracy: 0.9472 - val_loss: 0.1505 - val_accuracy: 0.9544
# Epoch 18/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1215 - accuracy: 0.9474 - val_loss: 0.1596 - val_accuracy: 0.9547
# Epoch 19/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1198 - accuracy: 0.9485 - val_loss: 0.1528 - val_accuracy: 0.9534
# Epoch 20/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1185 - accuracy: 0.9488 - val_loss: 0.1749 - val_accuracy: 0.9548
# Epoch 21/35
# 12/12 [==============================] - 0s 39ms/step - loss: 0.1212 - accuracy: 0.9482 - val_loss: 0.1652 - val_accuracy: 0.9418
# Epoch 22/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1180 - accuracy: 0.9495 - val_loss: 0.1402 - val_accuracy: 0.9545
# Epoch 23/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1196 - accuracy: 0.9492 - val_loss: 0.1383 - val_accuracy: 0.9542
# Epoch 24/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1186 - accuracy: 0.9487 - val_loss: 0.1411 - val_accuracy: 0.9546
# Epoch 25/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1156 - accuracy: 0.9500 - val_loss: 0.1473 - val_accuracy: 0.9548
# Epoch 26/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1158 - accuracy: 0.9497 - val_loss: 0.1790 - val_accuracy: 0.9533
# Epoch 27/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1138 - accuracy: 0.9507 - val_loss: 0.1707 - val_accuracy: 0.9536
# Epoch 28/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1122 - accuracy: 0.9517 - val_loss: 0.1666 - val_accuracy: 0.9533
# Epoch 29/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1116 - accuracy: 0.9522 - val_loss: 0.1607 - val_accuracy: 0.9525
# Epoch 30/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1150 - accuracy: 0.9513 - val_loss: 0.1629 - val_accuracy: 0.9492
# Epoch 31/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1134 - accuracy: 0.9522 - val_loss: 0.1393 - val_accuracy: 0.9524
# Epoch 32/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1137 - accuracy: 0.9509 - val_loss: 0.1589 - val_accuracy: 0.9531
# Epoch 33/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1132 - accuracy: 0.9513 - val_loss: 0.1572 - val_accuracy: 0.9541
# Epoch 34/35
# 12/12 [==============================] - 0s 38ms/step - loss: 0.1139 - accuracy: 0.9510 - val_loss: 0.1587 - val_accuracy: 0.9539
# Epoch 35/35
# 12/12 [==============================] - 0s 39ms/step - loss: 0.1128 - accuracy: 0.9519 - val_loss: 0.1765 - val_accuracy: 0.9524

# %%
#Evaluate the model
	# evaluate model
_, acc = model.evaluate(X_test, y_test)
print("Accuracy is = ", (acc * 100.0), "%")
# Out:
# 1/1 [==============================] - 0s 44ms/step - loss: 0.1765 - accuracy: 0.9524
# Accuracy is =  95.24416923522949 %

# %%
###
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
print(history.history)
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


##################################
# Out:
# {'loss': [1.2409545183181763, 0.9504601359367371, 0.6663758158683777, 0.3024895489215851, 0.20186926424503326, 0.18169669806957245, 0.16258952021598816, 0.1496863216161728, 0.14240850508213043, 0.13490422070026398, 0.13341183960437775, 0.13079889118671417, 0.1286230832338333, 0.12669594585895538, 0.12379363179206848, 0.12336015701293945, 0.12278273701667786, 0.12153310328722, 0.11978050321340561, 0.11848179250955582, 0.12117278575897217, 0.11799659579992294, 0.1196465864777565, 0.11859927326440811, 0.11561685800552368, 0.11582228541374207, 0.11380553990602493, 0.11217587441205978, 0.11157217621803284, 0.11502310633659363, 0.1133798286318779, 0.11367905884981155, 0.11321703344583511, 0.1139179989695549, 0.11278405785560608], 'accuracy': [0.7009530663490295, 0.8213363885879517, 0.8221186399459839, 0.9004969000816345, 0.9283031821250916, 0.9323979616165161, 0.9376461505889893, 0.9403395652770996, 0.9424305558204651, 0.9444738030433655, 0.9446261525154114, 0.9452352523803711, 0.9456525444984436, 0.9462450742721558, 0.9473615288734436, 0.9473686218261719, 0.9472157955169678, 0.9473910331726074, 0.9485008716583252, 0.9487690925598145, 0.9481886029243469, 0.9494554400444031, 0.9491515159606934, 0.9487313032150269, 0.9499827027320862, 0.9497319459915161, 0.9507496356964111, 0.9516908526420593, 0.9522111415863037, 0.9513068199157715, 0.9522343873977661, 0.9509456157684326, 0.9512794017791748, 0.9510045647621155, 0.951878547668457], 'val_loss': [1.0125657320022583, 0.8544849753379822, 0.42988088726997375, 0.20366041362285614, 0.23832246661186218, 0.15624424815177917, 0.1463814079761505, 0.13917747139930725, 0.1391511708498001, 0.1368977427482605, 0.13476179540157318, 0.13826926052570343, 0.14621220529079437, 0.138579323887825, 0.13995066285133362, 0.14861416816711426, 0.15052558481693268, 0.15955697000026703, 0.15284259617328644, 0.17487461864948273, 0.16520635783672333, 0.14018715918064117, 0.1383437067270279, 0.14106720685958862, 0.1472601592540741, 0.17896731197834015, 0.1707001030445099, 0.1666104942560196, 0.16073846817016602, 0.16293752193450928, 0.13928517699241638, 0.15891067683696747, 0.1572345644235611, 0.1587294340133667, 0.17645080387592316], 'val_accuracy': [0.892620861530304, 0.8302005529403687, 0.8445813655853271, 0.9408026337623596, 0.9187517166137695, 0.9446747303009033, 0.9467816352844238, 0.9500927925109863, 0.9490479230880737, 0.95033198595047, 0.952840268611908, 0.9539962410926819, 0.9538310766220093, 0.9539364576339722, 0.9536687731742859, 0.9537485241889954, 0.954426109790802, 0.9546653032302856, 0.953355610370636, 0.9548190236091614, 0.9417763948440552, 0.9545400142669678, 0.9541584849357605, 0.954562783241272, 0.954793393611908, 0.9532759189605713, 0.9536374807357788, 0.9532502889633179, 0.9525014758110046, 0.9491561055183411, 0.952433168888092, 0.9531107544898987, 0.9540987014770508, 0.953933596611023, 0.9524416923522949]}

# %%
##################################
#model = get_model()
model.load_weights('test.hdf5')  
#model.load_weights('sandstone_50_epochs_catXentropy_acc_with_weights.hdf5')  

#IoU
# %time
y_pred=model.predict(X_test)
print(y_pred.shape)
y_pred_argmax=np.argmax(y_pred, axis=3)
print(y_pred_argmax.shape)

##################################################
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.72 µs
# 1/1 [==============================] - 0s 17ms/step
# (7, 224, 224, 3)
# (7, 224, 224)

# %%
##################################################
#Using built in keras function
from keras.metrics import MeanIoU
n_classes = 3
testIndex = 3
IOU_keras = MeanIoU(num_classes=n_classes)  
# print(y_test[0,:,:,0].shape)
# print(y_pred_argmax[0,:,:].shape)
iou1 = IOU_keras.update_state(y_test[testIndex,:,:,0], np.around(y_pred[testIndex,:,:,0],decimals=0))
print("#1: " + str(IOU_keras.result().numpy()))
res1 = IOU_keras.result().numpy()

iou2 = IOU_keras.update_state(y_test[testIndex,:,:,1], np.around(y_pred[testIndex,:,:,1],decimals=0))
print("#2: " + str(IOU_keras.result().numpy()))
res2 = IOU_keras.result().numpy()

iou3 = IOU_keras.update_state(y_test[testIndex,:,:,2], np.around(y_pred[testIndex,:,:,2],decimals=0))
print("#3: " + str(IOU_keras.result().numpy()))
res3 = IOU_keras.result().numpy()

print("avg: " + str((res1+res2+res3)/3))
print("Mean IoU =", IOU_keras.result().numpy())


#To calculate I0U for each class...
# values = np.array(IOU_keras.get_weights()).reshape(n_classes, n_classes)
# print(values)
# print(train_masks[0].shape)
# print(train_images[0,:,:,:].shape)
# print(y_pred_argmax.shape)
# class1_IoU = values[0,0]/(values[0,0] + values[0,1] + values[0,2] + values[1,0]+ values[2,0])
# class2_IoU = values[1,1]/(values[1,1] + values[1,0] + values[1,2] + values[0,1]+ values[2,1])
# class3_IoU = values[2,2]/(values[2,2] + values[2,0] + values[2,1] + values[0,2]+ values[1,2])

# print("IoU for class1 is: ", class1_IoU)
# print("IoU for class2 is: ", class2_IoU)
# print("IoU for class3 is: ", class3_IoU)

# imgplot = plt.imshow(X_test[testIndex,:,:,:], cmap='viridis')
# plt.show()
# imgplot = plt.imshow(255*y_test[testIndex], cmap='viridis')
# plt.show()
# imgplot = plt.imshow(np.around(y_pred[testIndex],decimals=0), cmap='viridis')
# plt.show()
# imgplot = plt.imshow(y_pred_argmax[testIndex])
# plt.show()

#######################################################################
# Out:
# #1: 0.8481938
# #2: 0.9242418
# #3: 0.9800662
# avg: 0.9175006548563639
# Mean IoU = 0.9800662

# %%
#evaluate other metric for accuracy
#https://datascience.stackexchange.com/questions/45165/how-to-get-accuracy-f1-precision-and-recall-for-a-keras-model

from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc',f1_m,precision_m, recall_m])

# evaluate the model
loss, accuracy, f1_score, precision, recall = model.evaluate(y_pred, y_test, verbose=0)
print(f1_score)
# Out:
# 0.772977888584137

# %%
#######################################################################
#Predict on a few images
#model = get_model()
#model.load_weights('???.hdf5')  
import random
test_img_number = random.randint(0, len(X_test)-1)
test_img = X_test[test_img_number]
# print(test_img.shape)
ground_truth=y_test[test_img_number]
test_img_norm=test_img[:,:,0][:,:,None]
test = np.squeeze(test_img)
plt.figure(figsize=(12, 8))
plt.subplot(221)
plt.title('test')
imgplot = plt.imshow(test,cmap='viridis')
plt.subplot(222)
plt.title('testMask')
imgplot = plt.imshow(255*np.squeeze(ground_truth),cmap='viridis')
plt.show()
print(test_img.shape)
four_dim = np.expand_dims(test_img, axis = 0)

prediction = (model.predict(four_dim))
predicted_img=np.argmax(prediction, axis=3)[0,:,:]


plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img, cmap='viridis')
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(255*ground_truth, cmap='viridis')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(predicted_img, cmap='viridis')
fig = plt.gcf()
num = random.randint(0,100)
plt.savefig("/content/drive/MyDrive/Coral_Reef_Metadata/SavedFigs/this_plt"+str(num))
plt.show()

#####################################################################
# Out:
# (224, 224, 3)
# 1/1 [==============================] - 0s 223ms/step

# %%
for i in range(X_test.shape[0]):
  test_img = X_test[i]
  # print(test_img.shape)
  ground_truth=y_test[i]
  test_img_norm=test_img[:,:,0][:,:,None]
  four_dim = np.expand_dims(test_img, axis = 0)

  prediction = (model.predict(four_dim))
  predicted_img=np.argmax(prediction, axis=3)[0,:,:]
  plt.figure(figsize=(12, 8))
  plt.subplot(231)
  plt.title('Testing Image')
  plt.imshow(test_img, cmap='viridis')
  plt.subplot(232)
  plt.title('Testing Label')
  plt.imshow(255*ground_truth, cmap='viridis')
  plt.subplot(233)
  plt.title('Prediction on test image')
  plt.imshow(predicted_img, cmap='viridis')
  fig = plt.gcf()
  num = random.randint(0,100)
  plt.savefig("/content/drive/MyDrive/Coral_Reef_Metadata/SavedFigs/this_plt"+str(num))
  plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
