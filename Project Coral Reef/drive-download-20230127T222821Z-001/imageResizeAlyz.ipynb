# %%
import os 
import numpy as np 
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2 as cv

# %% [markdown]
# ## set file path

# %%
path = "annotatedFiles/"

# %%
contents = os.listdir(path)
#plt.add_subplot()
for item in contents:
    if item.endswith(".npz"):
        arr1 = np.load(path+item)
        print(item)
        label = (arr1["label"])
        eightBit = label*255
        img1 = eightBit
#         print(label.shape)
        #pyplot.imshow(eightBit)
        #print(label)
        img = cv.resize(eightBit, (128,128))
        imgplot = plt.imshow(img,cmap='viridis')
        plt.title("small")
        plt.show()
        plt.title("large")
        imgplot = plt.imshow(img1,cmap='viridis')
        plt.show()
# Out:
# _edgesI_MU_Ile_Raphael_NIR_Enter-user-ID.npz
# _edgesI_MV_Maldives_Group_16_NIR_GD.npz
# _edgesA_BZ_Lighthouse_Reef_NIR_gd.npz
# _edgesI_MV_Maldives_Group_7_NIR_GD.npz
# _edgesI_IN_Kitlan_Island_NIR_Enter-user-ID.npz
# _edgesA_BZ_Glovers Reef_NIR_gd.npz
# _edgesI_IN_Kadmat_Island_NIR_Enter-user-ID.npz
# _edgesI_GB_Saloman_NIR_GD.npz
# _edgesA_MX_Chinchorro_Bank_NIR_GD.npz
# _edgesA_BS_Mira-por-vos_Islets_NIR_GD.npz
# _edgesI_MU_Mapare_Islet_NIR_Enter-user-ID.npz
# _edgesI_IN_Agatti_Atoll_NIR_Enter-user-ID.npz
# _edgesI_MV_Maldives_Group_18_NIR_GD.npz

# %%
for item in contents:
    if item.endswith("Agatti_Atoll_NIR_Enter-user-ID.npz"):
        arr1 = np.load(path+item)
        print(item)
        label = (arr1["000label"])
        label_ = arr1["label"]
        nineBit = label_*255
        eightBit = label*255
        img1 = eightBit
        img = nineBit
#         print(label.shape)
        #pyplot.imshow(eightBit)
        #print(label)
        imgplot = plt.imshow(img,cmap='viridis')
        plt.title("newest")
        plt.show()
        plt.title("orignial")
        imgplot = plt.imshow(img1,cmap='viridis')
        plt.show()
# Out:
# _edgesI_IN_Agatti_Atoll_NIR_Enter-user-ID.npz
